# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
# %matplotlib inline
sampFreq = 22050
sampFreq,sound = wavfile.read('./obama.wav')
sound = sound / 2.0**15
length_in_s = sound.shape[0] / sampFreq
time = np.arange(sound.shape[0]) / (sound.shape[0] * length_in_s)
signal = sound[:,0]

fft_spectrum = np.fft.rfft(signal)
freq = np.fft.rfftfreq(signal.size, d=1./sampFreq)

fft_spectrum

fft_spectrum_abs = np.abs(fft_spectrum)

for i,f in enumerate(fft_spectrum_abs):
    if f > 350: #looking at amplitudes of the spikes higher than 350 
        print('frequency = {} Hz with amplitude {} '.format(np.round(freq[i],4),  np.round(f,4)))
# Out:
# frequency = 96.0583 Hz with amplitude 373.7206
# frequency = 99.6102 Hz with amplitude 359.3
# frequency = 99.6891 Hz with amplitude 405.6896
# frequency = 100.6363 Hz with amplitude 364.0983
# frequency = 101.0309 Hz with amplitude 357.8384
# frequency = 101.1099 Hz with amplitude 559.15
# frequency = 101.1888 Hz with amplitude 588.5541
# frequency = 101.2677 Hz with amplitude 510.3439
# frequency = 101.3466 Hz with amplitude 449.921
# frequency = 101.4256 Hz with amplitude 418.3425
# frequency = 101.5045 Hz with amplitude 479.136
# frequency = 101.8202 Hz with amplitude 654.2095
# frequency = 101.8992 Hz with amplitude 427.0701
# frequency = 101.9781 Hz with amplitude 396.5435
# frequency = 102.057 Hz with amplitude 439.8439
# frequency = 102.136 Hz with amplitude 606.8255
# frequency = 102.2938 Hz with amplitude 438.8746
# frequency = 102.3727 Hz with amplitude 577.7871
# frequency = 102.4517 Hz with amplitude 542.1691
# frequency = 102.5306 Hz with amplitude 434.4812
# frequency = 102.6095 Hz with amplitude 351.0304
# frequency = 102.6885 Hz with amplitude 721.134
# frequency = 102.7674 Hz with amplitude 622.7711
# frequency = 102.8463 Hz with amplitude 414.4091
# frequency = 102.9253 Hz with amplitude 394.0423
# frequency = 103.0042 Hz with amplitude 468.1058
# frequency = 103.0831 Hz with amplitude 602.007
# frequency = 103.162 Hz with amplitude 557.0937
# frequency = 103.241 Hz with amplitude 443.6682
# frequency = 103.3199 Hz with amplitude 494.3609
# frequency = 103.3988 Hz with amplitude 501.1018
# frequency = 103.4778 Hz with amplitude 475.2273
# frequency = 103.6356 Hz with amplitude 453.9869
# frequency = 103.8724 Hz with amplitude 493.8188
# frequency = 104.0303 Hz with amplitude 555.8076
# frequency = 104.1092 Hz with amplitude 484.2261
# frequency = 104.1881 Hz with amplitude 375.7134
# frequency = 104.346 Hz with amplitude 354.5663
# frequency = 104.7407 Hz with amplitude 472.8536
# frequency = 105.0564 Hz with amplitude 391.4727
# frequency = 105.3721 Hz with amplitude 478.9201
# frequency = 105.8457 Hz with amplitude 382.3393
# frequency = 106.3193 Hz with amplitude 525.738
# frequency = 109.3976 Hz with amplitude 392.3805
# frequency = 109.5554 Hz with amplitude 410.4156
# frequency = 111.6076 Hz with amplitude 389.2413
# frequency = 111.8444 Hz with amplitude 391.1263
# frequency = 112.4758 Hz with amplitude 358.2307
# frequency = 112.7126 Hz with amplitude 428.2247
# frequency = 112.7916 Hz with amplitude 385.0601
# frequency = 113.2651 Hz with amplitude 361.8097
# frequency = 113.9755 Hz with amplitude 366.8428
# frequency = 114.3702 Hz with amplitude 364.1341
# frequency = 114.6859 Hz with amplitude 437.7013
# frequency = 114.9227 Hz with amplitude 499.3915
# frequency = 115.0016 Hz with amplitude 405.2195
# frequency = 115.0805 Hz with amplitude 534.8872
# frequency = 115.712 Hz with amplitude 391.7016
# frequency = 116.5013 Hz with amplitude 442.9493
# frequency = 116.9749 Hz with amplitude 561.241
# frequency = 117.1327 Hz with amplitude 593.3206
# frequency = 117.2117 Hz with amplitude 357.716
# frequency = 117.3695 Hz with amplitude 378.035
# frequency = 117.4485 Hz with amplitude 400.2432
# frequency = 117.7642 Hz with amplitude 444.048
# frequency = 117.922 Hz with amplitude 351.014
# frequency = 118.0799 Hz with amplitude 467.3168
# frequency = 118.1588 Hz with amplitude 589.5201
# frequency = 118.3167 Hz with amplitude 434.7586
# frequency = 118.3956 Hz with amplitude 397.6444
# frequency = 118.4745 Hz with amplitude 515.7389
# frequency = 118.6324 Hz with amplitude 476.2708
# frequency = 118.7113 Hz with amplitude 353.1483
# frequency = 118.8692 Hz with amplitude 414.9941
# frequency = 118.9481 Hz with amplitude 394.4647
# frequency = 119.0271 Hz with amplitude 433.1176
# frequency = 119.1849 Hz with amplitude 465.8678
# frequency = 119.2639 Hz with amplitude 567.8205
# frequency = 119.4217 Hz with amplitude 619.7644
# frequency = 119.5006 Hz with amplitude 618.4719
# frequency = 119.6585 Hz with amplitude 1292.4698
# frequency = 119.7374 Hz with amplitude 1315.2579
# frequency = 119.8164 Hz with amplitude 780.9296
# frequency = 119.8953 Hz with amplitude 2857.7661
# frequency = 120.0532 Hz with amplitude 915.5137
# frequency = 120.1321 Hz with amplitude 408.4491
# frequency = 120.2899 Hz with amplitude 798.3693
# frequency = 120.3689 Hz with amplitude 729.326
# frequency = 120.4478 Hz with amplitude 779.03
# frequency = 120.5267 Hz with amplitude 514.8493
# frequency = 120.6057 Hz with amplitude 414.0532
# frequency = 120.7635 Hz with amplitude 586.9603
# frequency = 120.8425 Hz with amplitude 684.596
# frequency = 121.1582 Hz with amplitude 533.4815
# frequency = 121.395 Hz with amplitude 497.7277
# frequency = 121.4739 Hz with amplitude 441.3345
# frequency = 121.5528 Hz with amplitude 459.1268
# frequency = 121.7107 Hz with amplitude 548.2715
# frequency = 121.7896 Hz with amplitude 362.3199
# frequency = 121.9475 Hz with amplitude 475.1455
# frequency = 122.1053 Hz with amplitude 461.7843
# frequency = 122.1843 Hz with amplitude 620.5704
# frequency = 122.7368 Hz with amplitude 366.2784
# frequency = 122.8157 Hz with amplitude 492.9978
# frequency = 122.8947 Hz with amplitude 370.9919
# frequency = 122.9736 Hz with amplitude 430.9109
# frequency = 123.2104 Hz with amplitude 520.3783
# frequency = 123.3682 Hz with amplitude 583.5104
# frequency = 123.4472 Hz with amplitude 537.8586
# frequency = 123.605 Hz with amplitude 792.9114
# frequency = 123.7629 Hz with amplitude 564.4179
# frequency = 123.8418 Hz with amplitude 541.6694
# frequency = 123.9207 Hz with amplitude 702.2385
# frequency = 123.9997 Hz with amplitude 566.2612
# frequency = 124.0786 Hz with amplitude 419.857
# frequency = 124.6311 Hz with amplitude 353.6057
# frequency = 124.7101 Hz with amplitude 402.3449
# frequency = 124.789 Hz with amplitude 452.4367
# frequency = 125.1836 Hz with amplitude 375.7966
# frequency = 125.6572 Hz with amplitude 362.9827
# frequency = 125.894 Hz with amplitude 518.7072
# frequency = 126.1308 Hz with amplitude 427.4627
# frequency = 126.3676 Hz with amplitude 683.9475
# frequency = 126.4465 Hz with amplitude 572.3994
# frequency = 126.5255 Hz with amplitude 527.1173
# frequency = 126.6044 Hz with amplitude 357.4681
# frequency = 126.999 Hz with amplitude 724.6985
# frequency = 127.1569 Hz with amplitude 445.6166
# frequency = 127.2358 Hz with amplitude 522.8634
# frequency = 127.5515 Hz with amplitude 759.6368
# frequency = 127.6305 Hz with amplitude 871.4623
# frequency = 127.7094 Hz with amplitude 435.9414
# frequency = 127.7883 Hz with amplitude 377.8871
# frequency = 128.0251 Hz with amplitude 353.8575
# frequency = 128.183 Hz with amplitude 716.0505
# frequency = 128.2619 Hz with amplitude 620.0343
# frequency = 128.4987 Hz with amplitude 402.6013
# frequency = 128.5776 Hz with amplitude 456.3695
# frequency = 128.6566 Hz with amplitude 398.8419
# frequency = 128.7355 Hz with amplitude 548.2614
# frequency = 128.8144 Hz with amplitude 682.7959
# frequency = 128.8934 Hz with amplitude 501.9491
# frequency = 129.0512 Hz with amplitude 401.9154
# frequency = 129.1302 Hz with amplitude 407.0795
# frequency = 129.2091 Hz with amplitude 432.285
# frequency = 129.288 Hz with amplitude 463.9543
# frequency = 129.3669 Hz with amplitude 362.2672
# frequency = 129.4459 Hz with amplitude 389.3081
# frequency = 129.5248 Hz with amplitude 580.8593
# frequency = 129.6827 Hz with amplitude 426.2093
# frequency = 129.7616 Hz with amplitude 477.8088
# frequency = 129.8405 Hz with amplitude 655.6073
# frequency = 129.9195 Hz with amplitude 366.924
# frequency = 129.9984 Hz with amplitude 563.0873
# frequency = 130.0773 Hz with amplitude 493.5471
# frequency = 130.1562 Hz with amplitude 654.9768
# frequency = 130.2352 Hz with amplitude 426.2493
# frequency = 130.393 Hz with amplitude 440.6995
# frequency = 130.5509 Hz with amplitude 546.4904
# frequency = 130.6298 Hz with amplitude 773.85
# frequency = 130.7877 Hz with amplitude 383.8565
# frequency = 130.8666 Hz with amplitude 381.1623
# frequency = 131.1034 Hz with amplitude 954.4265
# frequency = 131.1823 Hz with amplitude 581.8028
# frequency = 131.2613 Hz with amplitude 676.1127
# frequency = 131.3402 Hz with amplitude 482.7675
# frequency = 131.4191 Hz with amplitude 607.7655
# frequency = 131.577 Hz with amplitude 412.5741
# frequency = 131.6559 Hz with amplitude 603.2843
# frequency = 132.0506 Hz with amplitude 572.2002
# frequency = 132.2084 Hz with amplitude 926.551
# frequency = 132.2874 Hz with amplitude 1008.9408
# frequency = 132.3663 Hz with amplitude 473.2711
# frequency = 132.5242 Hz with amplitude 580.2989
# frequency = 132.6031 Hz with amplitude 653.6827
# frequency = 132.761 Hz with amplitude 510.7439
# frequency = 132.9188 Hz with amplitude 389.121
# frequency = 133.2345 Hz with amplitude 400.4204
# frequency = 133.5503 Hz with amplitude 391.9681
# frequency = 133.6292 Hz with amplitude 588.8817
# frequency = 133.7081 Hz with amplitude 618.4176
# frequency = 133.787 Hz with amplitude 482.6439
# frequency = 133.866 Hz with amplitude 572.8869
# frequency = 134.0238 Hz with amplitude 391.6383
# frequency = 134.1028 Hz with amplitude 513.1678
# frequency = 134.1817 Hz with amplitude 369.2943
# frequency = 134.2606 Hz with amplitude 873.8554
# frequency = 134.3396 Hz with amplitude 535.3244
# frequency = 134.4185 Hz with amplitude 386.3682
# frequency = 134.4974 Hz with amplitude 579.4774
# frequency = 134.5764 Hz with amplitude 383.3485
# frequency = 134.6553 Hz with amplitude 763.8653
# frequency = 134.7342 Hz with amplitude 751.7053
# frequency = 134.8921 Hz with amplitude 624.744
# frequency = 134.971 Hz with amplitude 379.4388
# frequency = 135.0499 Hz with amplitude 545.5458
# frequency = 135.1289 Hz with amplitude 788.2585
# frequency = 135.2078 Hz with amplitude 618.3799
# frequency = 135.2867 Hz with amplitude 545.7584
# frequency = 135.3657 Hz with amplitude 470.3145
# frequency = 135.4446 Hz with amplitude 946.8288
# frequency = 135.5235 Hz with amplitude 421.3117
# frequency = 135.6024 Hz with amplitude 623.5931
# frequency = 135.7603 Hz with amplitude 1068.2245
# frequency = 135.8392 Hz with amplitude 474.7915
# frequency = 135.9182 Hz with amplitude 863.2479
# frequency = 135.9971 Hz with amplitude 602.4059
# frequency = 136.076 Hz with amplitude 691.0103
# frequency = 136.155 Hz with amplitude 453.7677
# frequency = 136.2339 Hz with amplitude 541.7503
# frequency = 136.3128 Hz with amplitude 519.5261
# frequency = 136.4707 Hz with amplitude 399.4175
# frequency = 136.5496 Hz with amplitude 859.7002
# frequency = 136.7864 Hz with amplitude 565.6825
# frequency = 136.8653 Hz with amplitude 395.7281
# frequency = 137.0232 Hz with amplitude 648.4869
# frequency = 137.1021 Hz with amplitude 465.9837
# frequency = 137.1811 Hz with amplitude 754.224
# frequency = 137.26 Hz with amplitude 715.5313
# frequency = 137.4178 Hz with amplitude 639.674
# frequency = 137.4968 Hz with amplitude 602.6611
# frequency = 137.6546 Hz with amplitude 814.8227
# frequency = 137.8125 Hz with amplitude 362.8074
# frequency = 137.8914 Hz with amplitude 405.7046
# frequency = 137.9704 Hz with amplitude 565.8556
# frequency = 138.0493 Hz with amplitude 390.8991
# frequency = 138.2072 Hz with amplitude 794.7213
# frequency = 138.2861 Hz with amplitude 1218.6137
# frequency = 138.365 Hz with amplitude 667.9928
# frequency = 138.4439 Hz with amplitude 1275.9678
# frequency = 138.5229 Hz with amplitude 372.6617
# frequency = 138.6018 Hz with amplitude 516.267
# frequency = 138.7597 Hz with amplitude 718.8298
# frequency = 138.8386 Hz with amplitude 598.9761
# frequency = 138.9175 Hz with amplitude 760.9198
# frequency = 138.9965 Hz with amplitude 718.099
# frequency = 139.0754 Hz with amplitude 693.4035
# frequency = 139.1543 Hz with amplitude 583.8898
# frequency = 139.2332 Hz with amplitude 546.3243
# frequency = 139.3911 Hz with amplitude 1301.1538
# frequency = 139.47 Hz with amplitude 596.0701
# frequency = 139.549 Hz with amplitude 773.6565
# frequency = 139.6279 Hz with amplitude 886.584
# frequency = 139.7858 Hz with amplitude 1234.035
# frequency = 139.8647 Hz with amplitude 1045.0143
# frequency = 139.9436 Hz with amplitude 615.0842
# frequency = 140.0226 Hz with amplitude 654.2566
# frequency = 140.1015 Hz with amplitude 612.4378
# frequency = 140.1804 Hz with amplitude 361.923
# frequency = 140.4172 Hz with amplitude 450.5897
# frequency = 140.4961 Hz with amplitude 512.6558
# frequency = 140.5751 Hz with amplitude 1119.7788
# frequency = 140.654 Hz with amplitude 717.4435
# frequency = 140.7329 Hz with amplitude 674.8605
# frequency = 140.8119 Hz with amplitude 426.224
# frequency = 141.2065 Hz with amplitude 1167.9874
# frequency = 141.2854 Hz with amplitude 408.6346
# frequency = 141.3644 Hz with amplitude 573.726
# frequency = 141.6012 Hz with amplitude 418.9722
# frequency = 141.759 Hz with amplitude 919.9277
# frequency = 141.9169 Hz with amplitude 1363.8028
# frequency = 141.9958 Hz with amplitude 600.8041
# frequency = 142.0747 Hz with amplitude 1031.3805
# frequency = 142.1537 Hz with amplitude 488.1282
# frequency = 142.2326 Hz with amplitude 746.296
# frequency = 142.3115 Hz with amplitude 768.7541
# frequency = 142.3905 Hz with amplitude 702.1668
# frequency = 142.4694 Hz with amplitude 384.2515
# frequency = 142.5483 Hz with amplitude 831.5439
# frequency = 142.6273 Hz with amplitude 1630.5462
# frequency = 142.7062 Hz with amplitude 422.0924
# frequency = 142.7851 Hz with amplitude 360.0604
# frequency = 142.864 Hz with amplitude 1311.4781
# frequency = 142.943 Hz with amplitude 915.125
# frequency = 143.0219 Hz with amplitude 785.4962
# frequency = 143.1008 Hz with amplitude 612.6314
# frequency = 143.1798 Hz with amplitude 657.1658
# frequency = 143.2587 Hz with amplitude 1713.3746
# frequency = 143.3376 Hz with amplitude 986.003
# frequency = 143.4166 Hz with amplitude 995.5542
# frequency = 143.4955 Hz with amplitude 808.7947
# frequency = 143.5744 Hz with amplitude 540.7595
# frequency = 143.6534 Hz with amplitude 533.5186
# frequency = 143.7323 Hz with amplitude 1293.1455
# frequency = 143.8901 Hz with amplitude 880.516
# frequency = 143.9691 Hz with amplitude 747.8517
# frequency = 144.048 Hz with amplitude 598.1992
# frequency = 144.2059 Hz with amplitude 674.3052
# frequency = 144.2848 Hz with amplitude 1290.4796
# frequency = 144.3637 Hz with amplitude 809.5474
# frequency = 144.4427 Hz with amplitude 387.5922
# frequency = 144.5216 Hz with amplitude 501.0304
# frequency = 144.6794 Hz with amplitude 1350.3349
# frequency = 144.9162 Hz with amplitude 1107.9462
# frequency = 144.9952 Hz with amplitude 416.4796
# frequency = 145.0741 Hz with amplitude 837.388
# frequency = 145.232 Hz with amplitude 764.0591
# frequency = 145.3109 Hz with amplitude 724.1322
# frequency = 145.4688 Hz with amplitude 996.7385
# frequency = 145.5477 Hz with amplitude 1000.73
# frequency = 145.7055 Hz with amplitude 999.949
# frequency = 145.7845 Hz with amplitude 589.6158
# frequency = 145.8634 Hz with amplitude 611.6452
# frequency = 145.9423 Hz with amplitude 759.7654
# frequency = 146.0213 Hz with amplitude 543.8076
# frequency = 146.1002 Hz with amplitude 731.4033
# frequency = 146.1791 Hz with amplitude 1563.0957
# frequency = 146.2581 Hz with amplitude 695.2656
# frequency = 146.4159 Hz with amplitude 1505.9417
# frequency = 146.4948 Hz with amplitude 876.6222
# frequency = 146.5738 Hz with amplitude 2327.4675
# frequency = 146.6527 Hz with amplitude 598.1002
# frequency = 146.7316 Hz with amplitude 1901.4414
# frequency = 146.8106 Hz with amplitude 1196.5563
# frequency = 146.8895 Hz with amplitude 2498.0427
# frequency = 146.9684 Hz with amplitude 1182.2284
# frequency = 147.0474 Hz with amplitude 1233.7174
# frequency = 147.1263 Hz with amplitude 681.1914
# frequency = 147.2052 Hz with amplitude 1064.5122
# frequency = 147.2841 Hz with amplitude 1169.1407
# frequency = 147.3631 Hz with amplitude 2100.8401
# frequency = 147.5209 Hz with amplitude 1069.4118
# frequency = 147.5999 Hz with amplitude 371.4694
# frequency = 147.6788 Hz with amplitude 1305.7761
# frequency = 147.7577 Hz with amplitude 442.7862
# frequency = 147.8367 Hz with amplitude 1109.5003
# frequency = 147.9156 Hz with amplitude 1120.7314
# frequency = 147.9945 Hz with amplitude 907.717
# frequency = 148.0735 Hz with amplitude 597.0034
# frequency = 148.1524 Hz with amplitude 692.2448
# frequency = 148.2313 Hz with amplitude 912.7618
# frequency = 148.3102 Hz with amplitude 698.5089
# frequency = 148.4681 Hz with amplitude 705.4816
# frequency = 148.547 Hz with amplitude 1226.4563
# frequency = 148.626 Hz with amplitude 702.1176
# frequency = 148.7049 Hz with amplitude 610.5849
# frequency = 148.7838 Hz with amplitude 371.4737
# frequency = 148.8628 Hz with amplitude 419.6964
# frequency = 148.9417 Hz with amplitude 1502.2041
# frequency = 149.0206 Hz with amplitude 1240.8895
# frequency = 149.0995 Hz with amplitude 1199.8041
# frequency = 149.1785 Hz with amplitude 859.0613
# frequency = 149.2574 Hz with amplitude 1570.8133
# frequency = 149.3363 Hz with amplitude 698.2746
# frequency = 149.4153 Hz with amplitude 914.3763
# frequency = 149.4942 Hz with amplitude 631.9429
# frequency = 149.5731 Hz with amplitude 992.2485
# frequency = 149.6521 Hz with amplitude 931.7622
# frequency = 149.731 Hz with amplitude 510.8152
# frequency = 149.8099 Hz with amplitude 2265.1449
# frequency = 149.8889 Hz with amplitude 938.7741
# frequency = 149.9678 Hz with amplitude 540.0949
# frequency = 150.0467 Hz with amplitude 1700.7747
# frequency = 150.2046 Hz with amplitude 752.0949
# frequency = 150.2835 Hz with amplitude 696.1808
# frequency = 150.3624 Hz with amplitude 1939.8915
# frequency = 150.4414 Hz with amplitude 1777.6976
# frequency = 150.5203 Hz with amplitude 2135.4401
# frequency = 150.5992 Hz with amplitude 925.4623
# frequency = 150.6782 Hz with amplitude 509.8316
# frequency = 150.7571 Hz with amplitude 1015.9839
# frequency = 150.836 Hz with amplitude 503.9661
# frequency = 150.9939 Hz with amplitude 2062.2015
# frequency = 151.1517 Hz with amplitude 772.7214
# frequency = 151.2307 Hz with amplitude 1395.9656
# frequency = 151.3096 Hz with amplitude 1274.5478
# frequency = 151.3885 Hz with amplitude 1153.0807
# frequency = 151.5464 Hz with amplitude 2394.4835
# frequency = 151.6253 Hz with amplitude 741.6979
# frequency = 151.7043 Hz with amplitude 923.5246
# frequency = 151.7832 Hz with amplitude 825.2658
# frequency = 151.8621 Hz with amplitude 460.0586
# frequency = 151.941 Hz with amplitude 1257.6388
# frequency = 152.02 Hz with amplitude 1458.0589
# frequency = 152.0989 Hz with amplitude 551.7445
# frequency = 152.1778 Hz with amplitude 1597.0788
# frequency = 152.2568 Hz with amplitude 739.0178
# frequency = 152.3357 Hz with amplitude 817.6986
# frequency = 152.4146 Hz with amplitude 1306.4821
# frequency = 152.4936 Hz with amplitude 729.8215
# frequency = 152.5725 Hz with amplitude 1720.9331
# frequency = 152.6514 Hz with amplitude 2447.6472
# frequency = 152.7303 Hz with amplitude 1400.1375
# frequency = 152.8093 Hz with amplitude 876.2612
# frequency = 152.8882 Hz with amplitude 417.9289
# frequency = 153.0461 Hz with amplitude 1524.8663
# frequency = 153.125 Hz with amplitude 679.0141
# frequency = 153.2039 Hz with amplitude 577.6085
# frequency = 153.2829 Hz with amplitude 684.7091
# frequency = 153.3618 Hz with amplitude 1166.7178
# frequency = 153.4407 Hz with amplitude 1595.4663
# frequency = 153.5197 Hz with amplitude 610.6874
# frequency = 153.5986 Hz with amplitude 1071.2912
# frequency = 153.6775 Hz with amplitude 923.4291
# frequency = 153.7564 Hz with amplitude 821.3428
# frequency = 153.8354 Hz with amplitude 1138.4772
# frequency = 153.9143 Hz with amplitude 2112.8109
# frequency = 153.9932 Hz with amplitude 594.2647
# frequency = 154.0722 Hz with amplitude 1173.1492
# frequency = 154.1511 Hz with amplitude 1097.8282
# frequency = 154.23 Hz with amplitude 1314.3809
# frequency = 154.309 Hz with amplitude 1867.4073
# frequency = 154.3879 Hz with amplitude 906.4791
# frequency = 154.4668 Hz with amplitude 1164.4479
# frequency = 154.5457 Hz with amplitude 736.6077
# frequency = 154.6247 Hz with amplitude 624.3189
# frequency = 154.7036 Hz with amplitude 1124.4019
# frequency = 154.7825 Hz with amplitude 1413.9607
# frequency = 154.8615 Hz with amplitude 1350.4248
# frequency = 154.9404 Hz with amplitude 1138.3073
# frequency = 155.0193 Hz with amplitude 2795.8279
# frequency = 155.0983 Hz with amplitude 1235.6153
# frequency = 155.1772 Hz with amplitude 1209.6355
# frequency = 155.2561 Hz with amplitude 519.7773
# frequency = 155.3351 Hz with amplitude 1286.9432
# frequency = 155.414 Hz with amplitude 1061.0604
# frequency = 155.4929 Hz with amplitude 478.7131
# frequency = 155.5718 Hz with amplitude 1105.5719
# frequency = 155.6508 Hz with amplitude 1872.8763
# frequency = 155.7297 Hz with amplitude 889.7636
# frequency = 155.8086 Hz with amplitude 385.6568
# frequency = 155.8876 Hz with amplitude 1623.7541
# frequency = 155.9665 Hz with amplitude 578.0626
# frequency = 156.0454 Hz with amplitude 697.8816
# frequency = 156.1244 Hz with amplitude 2254.9352
# frequency = 156.2822 Hz with amplitude 716.2659
# frequency = 156.3611 Hz with amplitude 1400.5956
# frequency = 156.4401 Hz with amplitude 1088.0553
# frequency = 156.5979 Hz with amplitude 1007.8784
# frequency = 156.6769 Hz with amplitude 1359.56
# frequency = 156.7558 Hz with amplitude 766.153
# frequency = 156.8347 Hz with amplitude 889.0061
# frequency = 156.9137 Hz with amplitude 1523.5581
# frequency = 156.9926 Hz with amplitude 479.277
# frequency = 157.0715 Hz with amplitude 761.4387
# frequency = 157.2294 Hz with amplitude 1979.0424
# frequency = 157.3083 Hz with amplitude 773.4479
# frequency = 157.3872 Hz with amplitude 1786.5284
# frequency = 157.4662 Hz with amplitude 1302.4859
# frequency = 157.5451 Hz with amplitude 1122.0419
# frequency = 157.624 Hz with amplitude 642.2335
# frequency = 157.703 Hz with amplitude 764.4416
# frequency = 157.7819 Hz with amplitude 1695.143
# frequency = 157.8608 Hz with amplitude 552.5082
# frequency = 157.9398 Hz with amplitude 1087.8465
# frequency = 158.0187 Hz with amplitude 815.9589
# frequency = 158.0976 Hz with amplitude 1310.7355
# frequency = 158.1765 Hz with amplitude 1468.1281
# frequency = 158.2555 Hz with amplitude 383.0835
# frequency = 158.3344 Hz with amplitude 1814.8297
# frequency = 158.4133 Hz with amplitude 1590.9479
# frequency = 158.4923 Hz with amplitude 504.5909
# frequency = 158.5712 Hz with amplitude 615.7054
# frequency = 158.6501 Hz with amplitude 1741.3172
# frequency = 158.7291 Hz with amplitude 2525.6599
# frequency = 158.8869 Hz with amplitude 1244.444
# frequency = 158.9659 Hz with amplitude 1928.9477
# frequency = 159.0448 Hz with amplitude 1112.4355
# frequency = 159.1237 Hz with amplitude 1113.8858
# frequency = 159.2026 Hz with amplitude 1118.1034
# frequency = 159.2816 Hz with amplitude 2279.6672
# frequency = 159.3605 Hz with amplitude 1734.2159
# frequency = 159.4394 Hz with amplitude 1583.3744
# frequency = 159.5184 Hz with amplitude 1948.3254
# frequency = 159.5973 Hz with amplitude 1278.1343
# frequency = 159.6762 Hz with amplitude 1062.4603
# frequency = 159.7552 Hz with amplitude 1502.998
# frequency = 159.8341 Hz with amplitude 1553.7136
# frequency = 159.913 Hz with amplitude 1096.6049
# frequency = 159.9919 Hz with amplitude 530.6742
# frequency = 160.0709 Hz with amplitude 1029.0699
# frequency = 160.1498 Hz with amplitude 961.7116
# frequency = 160.2287 Hz with amplitude 1754.8701
# frequency = 160.3077 Hz with amplitude 1296.9035
# frequency = 160.3866 Hz with amplitude 989.507
# frequency = 160.4655 Hz with amplitude 1548.9653
# frequency = 160.5445 Hz with amplitude 1448.022
# frequency = 160.6234 Hz with amplitude 1653.1696
# frequency = 160.7023 Hz with amplitude 572.0558
# frequency = 160.7812 Hz with amplitude 1323.8465
# frequency = 160.8602 Hz with amplitude 667.6644
# frequency = 160.9391 Hz with amplitude 1551.4443
# frequency = 161.018 Hz with amplitude 2490.8287
# frequency = 161.097 Hz with amplitude 1989.1924
# frequency = 161.1759 Hz with amplitude 1500.1493
# frequency = 161.2548 Hz with amplitude 422.121
# frequency = 161.3338 Hz with amplitude 1345.2716
# frequency = 161.4127 Hz with amplitude 1277.8552
# frequency = 161.5706 Hz with amplitude 1268.8261
# frequency = 161.6495 Hz with amplitude 2271.0976
# frequency = 161.7284 Hz with amplitude 602.6037
# frequency = 161.8863 Hz with amplitude 1559.892
# frequency = 161.9652 Hz with amplitude 512.4233
# frequency = 162.0441 Hz with amplitude 525.6924
# frequency = 162.1231 Hz with amplitude 2246.4216
# frequency = 162.202 Hz with amplitude 2033.8258
# frequency = 162.2809 Hz with amplitude 592.4276
# frequency = 162.3599 Hz with amplitude 924.8227
# frequency = 162.4388 Hz with amplitude 1371.0401
# frequency = 162.5177 Hz with amplitude 388.9321
# frequency = 162.5966 Hz with amplitude 983.1978
# frequency = 162.6756 Hz with amplitude 894.5776
# frequency = 162.7545 Hz with amplitude 2163.5242
# frequency = 162.8334 Hz with amplitude 738.6416
# frequency = 162.9124 Hz with amplitude 1235.2979
# frequency = 162.9913 Hz with amplitude 427.4996
# frequency = 163.0702 Hz with amplitude 1610.8449
# frequency = 163.1492 Hz with amplitude 701.2645
# frequency = 163.2281 Hz with amplitude 1693.4168
# frequency = 163.307 Hz with amplitude 1118.0632
# frequency = 163.386 Hz with amplitude 791.5441
# frequency = 163.4649 Hz with amplitude 3070.6588
# frequency = 163.5438 Hz with amplitude 812.2096
# frequency = 163.6227 Hz with amplitude 679.6089
# frequency = 163.7017 Hz with amplitude 1117.9977
# frequency = 163.7806 Hz with amplitude 1512.952
# frequency = 163.8595 Hz with amplitude 1245.9049
# frequency = 163.9385 Hz with amplitude 838.9608
# frequency = 164.0174 Hz with amplitude 1417.0803
# frequency = 164.0963 Hz with amplitude 2461.5175
# frequency = 164.1753 Hz with amplitude 1918.5908
# frequency = 164.2542 Hz with amplitude 1701.1806
# frequency = 164.3331 Hz with amplitude 769.3826
# frequency = 164.412 Hz with amplitude 354.2873
# frequency = 164.5699 Hz with amplitude 712.2585
# frequency = 164.6488 Hz with amplitude 1963.0026
# frequency = 164.7278 Hz with amplitude 1408.6896
# frequency = 164.8067 Hz with amplitude 1728.1894
# frequency = 164.8856 Hz with amplitude 501.7006
# frequency = 164.9646 Hz with amplitude 607.6217
# frequency = 165.0435 Hz with amplitude 1062.8431
# frequency = 165.1224 Hz with amplitude 907.8256
# frequency = 165.2014 Hz with amplitude 1056.1727
# frequency = 165.2803 Hz with amplitude 1969.3616
# frequency = 165.3592 Hz with amplitude 1215.0128
# frequency = 165.4381 Hz with amplitude 1730.4768
# frequency = 165.5171 Hz with amplitude 1581.7077
# frequency = 165.596 Hz with amplitude 2052.5146
# frequency = 165.6749 Hz with amplitude 1175.2623
# frequency = 165.8328 Hz with amplitude 1160.387
# frequency = 165.9117 Hz with amplitude 1650.7343
# frequency = 165.9907 Hz with amplitude 1057.2246
# frequency = 166.0696 Hz with amplitude 3105.3466
# frequency = 166.1485 Hz with amplitude 1758.048
# frequency = 166.2274 Hz with amplitude 811.6246
# frequency = 166.3064 Hz with amplitude 633.0633
# frequency = 166.3853 Hz with amplitude 1334.7474
# frequency = 166.4642 Hz with amplitude 894.7261
# frequency = 166.5432 Hz with amplitude 1948.3375
# frequency = 166.6221 Hz with amplitude 1610.8129
# frequency = 166.701 Hz with amplitude 2423.1959
# frequency = 166.78 Hz with amplitude 1226.0116
# frequency = 166.8589 Hz with amplitude 1638.9014
# frequency = 166.9378 Hz with amplitude 776.6863
# frequency = 167.0168 Hz with amplitude 771.0253
# frequency = 167.0957 Hz with amplitude 1138.5499
# frequency = 167.1746 Hz with amplitude 2586.7326
# frequency = 167.3325 Hz with amplitude 2254.706
# frequency = 167.4114 Hz with amplitude 2204.2747
# frequency = 167.5693 Hz with amplitude 582.4228
# frequency = 167.6482 Hz with amplitude 1653.9889
# frequency = 167.7271 Hz with amplitude 2095.4794
# frequency = 167.8061 Hz with amplitude 1080.5339
# frequency = 167.885 Hz with amplitude 1968.5513
# frequency = 167.9639 Hz with amplitude 2684.6683
# frequency = 168.0428 Hz with amplitude 1776.1058
# frequency = 168.1218 Hz with amplitude 1176.2623
# frequency = 168.2007 Hz with amplitude 1103.9188
# frequency = 168.2796 Hz with amplitude 916.7937
# frequency = 168.3586 Hz with amplitude 1902.8722
# frequency = 168.4375 Hz with amplitude 1603.0019
# frequency = 168.5164 Hz with amplitude 2500.6877
# frequency = 168.5954 Hz with amplitude 1637.4158
# frequency = 168.6743 Hz with amplitude 2477.832
# frequency = 168.7532 Hz with amplitude 3163.7258
# frequency = 168.8322 Hz with amplitude 1869.2745
# frequency = 168.9111 Hz with amplitude 2966.8543
# frequency = 168.99 Hz with amplitude 1595.5179
# frequency = 169.0689 Hz with amplitude 1031.6758
# frequency = 169.1479 Hz with amplitude 1917.6979
# frequency = 169.2268 Hz with amplitude 1492.6141
# frequency = 169.3057 Hz with amplitude 2066.6734
# frequency = 169.3847 Hz with amplitude 2725.8924
# frequency = 169.4636 Hz with amplitude 2644.1336
# frequency = 169.5425 Hz with amplitude 1833.6801
# frequency = 169.6215 Hz with amplitude 646.3874
# frequency = 169.7004 Hz with amplitude 1157.3004
# frequency = 169.7793 Hz with amplitude 1957.2397
# frequency = 169.8582 Hz with amplitude 412.9926
# frequency = 169.9372 Hz with amplitude 2146.3833
# frequency = 170.0161 Hz with amplitude 1326.0387
# frequency = 170.095 Hz with amplitude 1736.6969
# frequency = 170.174 Hz with amplitude 1643.4817
# frequency = 170.2529 Hz with amplitude 1547.5139
# frequency = 170.3318 Hz with amplitude 867.5271
# frequency = 170.4108 Hz with amplitude 841.1469
# frequency = 170.4897 Hz with amplitude 1529.3374
# frequency = 170.5686 Hz with amplitude 1779.0861
# frequency = 170.6476 Hz with amplitude 2173.7046
# frequency = 170.7265 Hz with amplitude 819.8245
# frequency = 170.8054 Hz with amplitude 940.7861
# frequency = 170.8843 Hz with amplitude 966.1048
# frequency = 170.9633 Hz with amplitude 1136.6425
# frequency = 171.0422 Hz with amplitude 1872.9345
# frequency = 171.1211 Hz with amplitude 1296.4722
# frequency = 171.2001 Hz with amplitude 772.6069
# frequency = 171.279 Hz with amplitude 2531.6939
# frequency = 171.3579 Hz with amplitude 1913.8924
# frequency = 171.4369 Hz with amplitude 463.9249
# frequency = 171.5158 Hz with amplitude 1677.1519
# frequency = 171.5947 Hz with amplitude 894.7479
# frequency = 171.6736 Hz with amplitude 2436.8292
# frequency = 171.7526 Hz with amplitude 1772.1482
# frequency = 171.8315 Hz with amplitude 1319.1136
# frequency = 171.9104 Hz with amplitude 571.278
# frequency = 171.9894 Hz with amplitude 894.9502
# frequency = 172.0683 Hz with amplitude 1942.1178
# frequency = 172.1472 Hz with amplitude 1681.4834
# frequency = 172.2262 Hz with amplitude 1224.5109
# frequency = 172.3051 Hz with amplitude 1912.6929
# frequency = 172.384 Hz with amplitude 3465.149
# frequency = 172.463 Hz with amplitude 2182.8694
# frequency = 172.5419 Hz with amplitude 2495.8563
# frequency = 172.6208 Hz with amplitude 2047.6094
# frequency = 172.6997 Hz with amplitude 1914.5087
# frequency = 172.7787 Hz with amplitude 754.2304
# frequency = 172.8576 Hz with amplitude 2159.7424
# frequency = 172.9365 Hz with amplitude 1488.0499
# frequency = 173.0155 Hz with amplitude 3147.2261
# frequency = 173.0944 Hz with amplitude 1631.4236
# frequency = 173.1733 Hz with amplitude 2915.454
# frequency = 173.2523 Hz with amplitude 1892.2032
# frequency = 173.3312 Hz with amplitude 856.0449
# frequency = 173.4101 Hz with amplitude 1579.6654
# frequency = 173.489 Hz with amplitude 424.0494
# frequency = 173.568 Hz with amplitude 1055.9653
# frequency = 173.6469 Hz with amplitude 1534.5986
# frequency = 173.7258 Hz with amplitude 1016.4325
# frequency = 173.8048 Hz with amplitude 1703.5074
# frequency = 173.8837 Hz with amplitude 790.852
# frequency = 173.9626 Hz with amplitude 2165.8016
# frequency = 174.0416 Hz with amplitude 1627.3384
# frequency = 174.1205 Hz with amplitude 2504.8114
# frequency = 174.1994 Hz with amplitude 682.0201
# frequency = 174.2784 Hz with amplitude 2720.0009
# frequency = 174.3573 Hz with amplitude 1448.7703
# frequency = 174.4362 Hz with amplitude 1122.2082
# frequency = 174.5151 Hz with amplitude 2657.5554
# frequency = 174.673 Hz with amplitude 1940.0527
# frequency = 174.7519 Hz with amplitude 2084.7519
# frequency = 174.9098 Hz with amplitude 2087.9215
# frequency = 174.9887 Hz with amplitude 1237.9669
# frequency = 175.0677 Hz with amplitude 2224.8952
# frequency = 175.1466 Hz with amplitude 1683.6694
# frequency = 175.2255 Hz with amplitude 3698.8409
# frequency = 175.3044 Hz with amplitude 733.9082
# frequency = 175.3834 Hz with amplitude 482.6019
# frequency = 175.4623 Hz with amplitude 1724.2061
# frequency = 175.5412 Hz with amplitude 1181.5763
# frequency = 175.6202 Hz with amplitude 1724.0793
# frequency = 175.6991 Hz with amplitude 415.2387
# frequency = 175.778 Hz with amplitude 3292.0317
# frequency = 175.857 Hz with amplitude 2007.0183
# frequency = 175.9359 Hz with amplitude 2528.7151
# frequency = 176.0148 Hz with amplitude 1408.727
# frequency = 176.0938 Hz with amplitude 739.5779
# frequency = 176.1727 Hz with amplitude 1596.2067
# frequency = 176.2516 Hz with amplitude 1544.0186
# frequency = 176.3305 Hz with amplitude 2414.7907
# frequency = 176.4095 Hz with amplitude 2209.1569
# frequency = 176.4884 Hz with amplitude 1679.8009
# frequency = 176.5673 Hz with amplitude 2568.3867
# frequency = 176.6463 Hz with amplitude 3386.0061
# frequency = 176.7252 Hz with amplitude 1019.3528
# frequency = 176.8041 Hz with amplitude 1315.161
# frequency = 176.8831 Hz with amplitude 1161.8
# frequency = 176.962 Hz with amplitude 1132.0928
# frequency = 177.0409 Hz with amplitude 1067.7854
# frequency = 177.1198 Hz with amplitude 2159.1053
# frequency = 177.1988 Hz with amplitude 3122.6712
# frequency = 177.2777 Hz with amplitude 2228.9419
# frequency = 177.3566 Hz with amplitude 1333.7444
# frequency = 177.4356 Hz with amplitude 2601.3425
# frequency = 177.5145 Hz with amplitude 829.7731
# frequency = 177.5934 Hz with amplitude 1690.6126
# frequency = 177.6724 Hz with amplitude 1437.7434
# frequency = 177.7513 Hz with amplitude 2237.1883
# frequency = 177.8302 Hz with amplitude 3707.9889
# frequency = 177.9091 Hz with amplitude 1645.1346
# frequency = 177.9881 Hz with amplitude 1381.1091
# frequency = 178.067 Hz with amplitude 1366.9829
# frequency = 178.1459 Hz with amplitude 2458.4289
# frequency = 178.2249 Hz with amplitude 1531.6707
# frequency = 178.3038 Hz with amplitude 1875.7527
# frequency = 178.3827 Hz with amplitude 1985.0491
# frequency = 178.4617 Hz with amplitude 784.6199
# frequency = 178.5406 Hz with amplitude 1383.0428
# frequency = 178.6195 Hz with amplitude 577.8795
# frequency = 178.6985 Hz with amplitude 1285.131
# frequency = 178.8563 Hz with amplitude 759.8806
# frequency = 178.9352 Hz with amplitude 1904.9837
# frequency = 179.0142 Hz with amplitude 976.4421
# frequency = 179.0931 Hz with amplitude 813.5974
# frequency = 179.172 Hz with amplitude 2289.0702
# frequency = 179.251 Hz with amplitude 2422.0685
# frequency = 179.3299 Hz with amplitude 472.8743
# frequency = 179.4088 Hz with amplitude 1741.999
# frequency = 179.4878 Hz with amplitude 2386.1281
# frequency = 179.5667 Hz with amplitude 2274.7606
# frequency = 179.6456 Hz with amplitude 1539.7826
# frequency = 179.7245 Hz with amplitude 1239.209
# frequency = 179.8035 Hz with amplitude 1386.2694
# frequency = 179.8824 Hz with amplitude 3581.8034
# frequency = 179.9613 Hz with amplitude 2445.499
# frequency = 180.0403 Hz with amplitude 1310.7617
# frequency = 180.1192 Hz with amplitude 1561.5727
# frequency = 180.1981 Hz with amplitude 1376.0159
# frequency = 180.2771 Hz with amplitude 1983.4292
# frequency = 180.356 Hz with amplitude 1745.7188
# frequency = 180.4349 Hz with amplitude 1091.6266
# frequency = 180.5139 Hz with amplitude 1704.9573
# frequency = 180.5928 Hz with amplitude 1766.5574
# frequency = 180.6717 Hz with amplitude 1447.8978
# frequency = 180.7506 Hz with amplitude 1402.6912
# frequency = 180.8296 Hz with amplitude 725.1648
# frequency = 180.9085 Hz with amplitude 2097.165
# frequency = 180.9874 Hz with amplitude 836.8165
# frequency = 181.0664 Hz with amplitude 1242.6992
# frequency = 181.1453 Hz with amplitude 3303.2819
# frequency = 181.2242 Hz with amplitude 1135.7885
# frequency = 181.3032 Hz with amplitude 2424.6573
# frequency = 181.3821 Hz with amplitude 2174.8278
# frequency = 181.461 Hz with amplitude 3758.2487
# frequency = 181.5399 Hz with amplitude 575.2744
# frequency = 181.6189 Hz with amplitude 1436.0735
# frequency = 181.6978 Hz with amplitude 2674.5877
# frequency = 181.7767 Hz with amplitude 2044.4311
# frequency = 181.8557 Hz with amplitude 2905.4753
# frequency = 181.9346 Hz with amplitude 1646.9453
# frequency = 182.0135 Hz with amplitude 1428.9718
# frequency = 182.0925 Hz with amplitude 2494.7589
# frequency = 182.1714 Hz with amplitude 3205.005
# frequency = 182.2503 Hz with amplitude 2991.7071
# frequency = 182.3293 Hz with amplitude 1718.9955
# frequency = 182.4082 Hz with amplitude 1796.2095
# frequency = 182.4871 Hz with amplitude 1314.1502
# frequency = 182.566 Hz with amplitude 1195.2602
# frequency = 182.645 Hz with amplitude 2650.8241
# frequency = 182.7239 Hz with amplitude 1969.0996
# frequency = 182.8028 Hz with amplitude 1786.4794
# frequency = 182.8818 Hz with amplitude 1061.3087
# frequency = 182.9607 Hz with amplitude 1000.1102
# frequency = 183.0396 Hz with amplitude 1430.449
# frequency = 183.1186 Hz with amplitude 1612.3426
# frequency = 183.1975 Hz with amplitude 953.5041
# frequency = 183.2764 Hz with amplitude 2411.6549
# frequency = 183.3553 Hz with amplitude 1430.4175
# frequency = 183.4343 Hz with amplitude 978.9476
# frequency = 183.5132 Hz with amplitude 2943.8086
# frequency = 183.5921 Hz with amplitude 1539.6645
# frequency = 183.6711 Hz with amplitude 497.5929
# frequency = 183.75 Hz with amplitude 3994.863
# frequency = 183.8289 Hz with amplitude 924.3842
# frequency = 183.9079 Hz with amplitude 1925.2804
# frequency = 183.9868 Hz with amplitude 1520.1522
# frequency = 184.0657 Hz with amplitude 1629.426
# frequency = 184.1447 Hz with amplitude 1516.8619
# frequency = 184.2236 Hz with amplitude 2199.3595
# frequency = 184.3025 Hz with amplitude 2163.9563
# frequency = 184.3814 Hz with amplitude 1179.8401
# frequency = 184.4604 Hz with amplitude 1184.5251
# frequency = 184.5393 Hz with amplitude 460.5783
# frequency = 184.6182 Hz with amplitude 1519.7764
# frequency = 184.6972 Hz with amplitude 1807.3563
# frequency = 184.7761 Hz with amplitude 880.9806
# frequency = 184.855 Hz with amplitude 2038.9078
# frequency = 184.934 Hz with amplitude 2193.5304
# frequency = 185.0129 Hz with amplitude 1610.7623
# frequency = 185.0918 Hz with amplitude 1965.0901
# frequency = 185.1707 Hz with amplitude 483.9034
# frequency = 185.2497 Hz with amplitude 2368.9635
# frequency = 185.3286 Hz with amplitude 2048.2763
# frequency = 185.4075 Hz with amplitude 657.6166
# frequency = 185.4865 Hz with amplitude 1263.9018
# frequency = 185.5654 Hz with amplitude 1479.6711
# frequency = 185.6443 Hz with amplitude 3268.3444
# frequency = 185.7233 Hz with amplitude 1347.1372
# frequency = 185.8022 Hz with amplitude 1581.4891
# frequency = 185.8811 Hz with amplitude 1831.3336
# frequency = 185.9601 Hz with amplitude 1714.2353
# frequency = 186.039 Hz with amplitude 1265.3255
# frequency = 186.1179 Hz with amplitude 1882.5662
# frequency = 186.1968 Hz with amplitude 1577.0485
# frequency = 186.2758 Hz with amplitude 2058.6125
# frequency = 186.3547 Hz with amplitude 1299.476
# frequency = 186.4336 Hz with amplitude 1036.685
# frequency = 186.5126 Hz with amplitude 2211.9058
# frequency = 186.5915 Hz with amplitude 1026.928
# frequency = 186.6704 Hz with amplitude 1553.4235
# frequency = 186.7494 Hz with amplitude 814.2154
# frequency = 186.8283 Hz with amplitude 2826.2656
# frequency = 186.9072 Hz with amplitude 1132.4979
# frequency = 186.9861 Hz with amplitude 788.4836
# frequency = 187.0651 Hz with amplitude 1824.7774
# frequency = 187.144 Hz with amplitude 750.6864
# frequency = 187.2229 Hz with amplitude 404.5666
# frequency = 187.3019 Hz with amplitude 1387.471
# frequency = 187.3808 Hz with amplitude 1752.051
# frequency = 187.4597 Hz with amplitude 2061.7857
# frequency = 187.5387 Hz with amplitude 2550.6779
# frequency = 187.6176 Hz with amplitude 1158.259
# frequency = 187.6965 Hz with amplitude 2074.4201
# frequency = 187.7755 Hz with amplitude 1985.3839
# frequency = 187.8544 Hz with amplitude 2113.7245
# frequency = 187.9333 Hz with amplitude 383.7611
# frequency = 188.0122 Hz with amplitude 417.9667
# frequency = 188.0912 Hz with amplitude 2465.5008
# frequency = 188.1701 Hz with amplitude 1488.4611
# frequency = 188.328 Hz with amplitude 790.1416
# frequency = 188.4069 Hz with amplitude 1694.7415
# frequency = 188.5648 Hz with amplitude 2964.7861
# frequency = 188.6437 Hz with amplitude 997.1655
# frequency = 188.7226 Hz with amplitude 667.9032
# frequency = 188.8015 Hz with amplitude 457.0046
# frequency = 188.9594 Hz with amplitude 1380.809
# frequency = 189.0383 Hz with amplitude 2244.451
# frequency = 189.1173 Hz with amplitude 3788.2881
# frequency = 189.1962 Hz with amplitude 2018.2966
# frequency = 189.2751 Hz with amplitude 990.9323
# frequency = 189.3541 Hz with amplitude 990.8824
# frequency = 189.433 Hz with amplitude 2211.7899
# frequency = 189.5119 Hz with amplitude 1275.9871
# frequency = 189.5909 Hz with amplitude 3346.1304
# frequency = 189.6698 Hz with amplitude 1335.2221
# frequency = 189.7487 Hz with amplitude 1893.7353
# frequency = 189.8276 Hz with amplitude 1366.4188
# frequency = 189.9066 Hz with amplitude 447.1382
# frequency = 189.9855 Hz with amplitude 1921.8542
# frequency = 190.0644 Hz with amplitude 1086.3091
# frequency = 190.1434 Hz with amplitude 1064.7431
# frequency = 190.2223 Hz with amplitude 2527.1694
# frequency = 190.3012 Hz with amplitude 2764.8365
# frequency = 190.3802 Hz with amplitude 2234.9355
# frequency = 190.4591 Hz with amplitude 2189.5858
# frequency = 190.538 Hz with amplitude 2321.0307
# frequency = 190.6169 Hz with amplitude 1262.2381
# frequency = 190.6959 Hz with amplitude 408.4031
# frequency = 190.7748 Hz with amplitude 639.7063
# frequency = 190.8537 Hz with amplitude 993.9852
# frequency = 190.9327 Hz with amplitude 1291.2315
# frequency = 191.0116 Hz with amplitude 3521.9414
# frequency = 191.0905 Hz with amplitude 3406.9415
# frequency = 191.1695 Hz with amplitude 470.728
# frequency = 191.2484 Hz with amplitude 2379.3666
# frequency = 191.3273 Hz with amplitude 1971.1512
# frequency = 191.4062 Hz with amplitude 1245.1461
# frequency = 191.4852 Hz with amplitude 1402.5571
# frequency = 191.5641 Hz with amplitude 888.3366
# frequency = 191.643 Hz with amplitude 965.3919
# frequency = 191.722 Hz with amplitude 2831.9382
# frequency = 191.8009 Hz with amplitude 1399.4117
# frequency = 191.8798 Hz with amplitude 952.4052
# frequency = 191.9588 Hz with amplitude 2408.9434
# frequency = 192.0377 Hz with amplitude 1405.9641
# frequency = 192.1166 Hz with amplitude 1433.7422
# frequency = 192.1956 Hz with amplitude 779.2841
# frequency = 192.2745 Hz with amplitude 759.9218
# frequency = 192.3534 Hz with amplitude 1623.6251
# frequency = 192.4323 Hz with amplitude 1575.3747
# frequency = 192.5113 Hz with amplitude 1811.4035
# frequency = 192.5902 Hz with amplitude 1442.9032
# frequency = 192.6691 Hz with amplitude 1656.1257
# frequency = 192.7481 Hz with amplitude 372.8503
# frequency = 192.827 Hz with amplitude 2577.5869
# frequency = 192.9059 Hz with amplitude 1946.2638
# frequency = 192.9849 Hz with amplitude 673.5329
# frequency = 193.0638 Hz with amplitude 2375.0155
# frequency = 193.1427 Hz with amplitude 1014.9579
# frequency = 193.2216 Hz with amplitude 2237.8538
# frequency = 193.3006 Hz with amplitude 1243.8392
# frequency = 193.3795 Hz with amplitude 679.6288
# frequency = 193.4584 Hz with amplitude 1810.0207
# frequency = 193.5374 Hz with amplitude 1026.0027
# frequency = 193.6163 Hz with amplitude 723.0548
# frequency = 193.6952 Hz with amplitude 1967.4915
# frequency = 193.7742 Hz with amplitude 1716.8262
# frequency = 193.8531 Hz with amplitude 1687.6111
# frequency = 193.932 Hz with amplitude 1402.8718
# frequency = 194.011 Hz with amplitude 1055.0509
# frequency = 194.1688 Hz with amplitude 1278.9272
# frequency = 194.2477 Hz with amplitude 849.4226
# frequency = 194.3267 Hz with amplitude 1837.8409
# frequency = 194.4056 Hz with amplitude 1537.3995
# frequency = 194.4845 Hz with amplitude 1706.9493
# frequency = 194.5635 Hz with amplitude 3078.164
# frequency = 194.6424 Hz with amplitude 1339.5004
# frequency = 194.7213 Hz with amplitude 788.6369
# frequency = 194.8003 Hz with amplitude 1667.6527
# frequency = 194.8792 Hz with amplitude 2686.7804
# frequency = 194.9581 Hz with amplitude 1276.7996
# frequency = 195.037 Hz with amplitude 1387.809
# frequency = 195.116 Hz with amplitude 504.1882
# frequency = 195.1949 Hz with amplitude 3196.1294
# frequency = 195.2738 Hz with amplitude 963.1331
# frequency = 195.3528 Hz with amplitude 2077.3483
# frequency = 195.4317 Hz with amplitude 1587.0599
# frequency = 195.5106 Hz with amplitude 520.489
# frequency = 195.5896 Hz with amplitude 701.3516
# frequency = 195.6685 Hz with amplitude 1011.9889
# frequency = 195.7474 Hz with amplitude 1426.2635
# frequency = 195.8264 Hz with amplitude 2122.1412
# frequency = 195.9053 Hz with amplitude 1536.7216
# frequency = 195.9842 Hz with amplitude 1284.3011
# frequency = 196.0631 Hz with amplitude 2015.7046
# frequency = 196.1421 Hz with amplitude 572.593
# frequency = 196.221 Hz with amplitude 426.7904
# frequency = 196.2999 Hz with amplitude 1812.644
# frequency = 196.3789 Hz with amplitude 1922.6575
# frequency = 196.4578 Hz with amplitude 1891.3254
# frequency = 196.5367 Hz with amplitude 1926.4134
# frequency = 196.6946 Hz with amplitude 664.1807
# frequency = 196.7735 Hz with amplitude 452.9951
# frequency = 196.8524 Hz with amplitude 2127.0973
# frequency = 196.9314 Hz with amplitude 2868.5177
# frequency = 197.0103 Hz with amplitude 4157.2423
# frequency = 197.0892 Hz with amplitude 2270.5751
# frequency = 197.1682 Hz with amplitude 929.2671
# frequency = 197.2471 Hz with amplitude 648.7738
# frequency = 197.326 Hz with amplitude 1238.7319
# frequency = 197.405 Hz with amplitude 1629.2692
# frequency = 197.4839 Hz with amplitude 3885.1832
# frequency = 197.5628 Hz with amplitude 2306.4733
# frequency = 197.6418 Hz with amplitude 3580.8307
# frequency = 197.7207 Hz with amplitude 1027.5135
# frequency = 197.7996 Hz with amplitude 1167.0436
# frequency = 197.8785 Hz with amplitude 2352.4749
# frequency = 197.9575 Hz with amplitude 1775.0319
# frequency = 198.0364 Hz with amplitude 2693.9239
# frequency = 198.1153 Hz with amplitude 1940.8027
# frequency = 198.1943 Hz with amplitude 2260.2897
# frequency = 198.2732 Hz with amplitude 1297.7686
# frequency = 198.3521 Hz with amplitude 478.7062
# frequency = 198.4311 Hz with amplitude 2432.8438
# frequency = 198.5889 Hz with amplitude 1225.1753
# frequency = 198.6678 Hz with amplitude 650.1657
# frequency = 198.7468 Hz with amplitude 1084.0291
# frequency = 198.8257 Hz with amplitude 959.1417
# frequency = 198.9046 Hz with amplitude 1758.3485
# frequency = 198.9836 Hz with amplitude 1956.9792
# frequency = 199.0625 Hz with amplitude 2179.3202
# frequency = 199.1414 Hz with amplitude 2393.1025
# frequency = 199.2204 Hz with amplitude 2661.9095
# frequency = 199.3782 Hz with amplitude 564.5128
# frequency = 199.4572 Hz with amplitude 1032.9431
# frequency = 199.5361 Hz with amplitude 1122.964
# frequency = 199.615 Hz with amplitude 862.7686
# frequency = 199.6939 Hz with amplitude 1451.9348
# frequency = 199.7729 Hz with amplitude 2133.7525
# frequency = 199.8518 Hz with amplitude 1875.8089
# frequency = 199.9307 Hz with amplitude 552.6684
# frequency = 200.0097 Hz with amplitude 1052.2689
# frequency = 200.0886 Hz with amplitude 1187.4765
# frequency = 200.2465 Hz with amplitude 1520.669
# frequency = 200.3254 Hz with amplitude 993.6092
# frequency = 200.4043 Hz with amplitude 615.6326
# frequency = 200.4832 Hz with amplitude 1098.74
# frequency = 200.5622 Hz with amplitude 1887.58
# frequency = 200.6411 Hz with amplitude 1309.8541
# frequency = 200.72 Hz with amplitude 2461.0701
# frequency = 200.8779 Hz with amplitude 574.26
# frequency = 200.9568 Hz with amplitude 1257.4677
# frequency = 201.0358 Hz with amplitude 2167.1736
# frequency = 201.1147 Hz with amplitude 1351.0363
# ...
# frequency = 5556.8589 Hz with amplitude 393.7341
# frequency = 5557.885 Hz with amplitude 384.5063
# frequency = 5558.5954 Hz with amplitude 364.5762
# frequency = 5562.6208 Hz with amplitude 431.7103
# frequency = 5562.6997 Hz with amplitude 367.8362
# frequency = 5564.8309 Hz with amplitude 366.6436
# frequency = 5570.9085 Hz with amplitude 350.0823
# frequency = 5576.1968 Hz with amplitude 417.4963
# frequency = 5576.7494 Hz with amplitude 377.6101
# frequency = 5578.8805 Hz with amplitude 373.5789
# frequency = 5582.1956 Hz with amplitude 357.8445
# frequency = 5582.5902 Hz with amplitude 393.0488
# frequency = 5584.0899 Hz with amplitude 490.3669
# frequency = 5584.4056 Hz with amplitude 350.7201
# frequency = 5584.6424 Hz with amplitude 403.2961
# frequency = 5584.8792 Hz with amplitude 354.4685
# frequency = 5587.4839 Hz with amplitude 363.534
# frequency = 5594.114 Hz with amplitude 480.7312
# frequency = 5597.0345 Hz with amplitude 369.7328
# frequency = 5598.5341 Hz with amplitude 440.9639
# frequency = 5600.1917 Hz with amplitude 381.2877
# frequency = 5605.8747 Hz with amplitude 373.8159
# frequency = 5628.4488 Hz with amplitude 358.6241
# frequency = 5629.0802 Hz with amplitude 358.2396
# frequency = 5634.2896 Hz with amplitude 375.327
# frequency = 5636.0261 Hz with amplitude 360.1098
# frequency = 5637.2101 Hz with amplitude 360.1359
# frequency = 5647.7078 Hz with amplitude 386.5051
# frequency = 5648.4971 Hz with amplitude 371.5925
# frequency = 5649.8389 Hz with amplitude 386.1912
# frequency = 5652.3647 Hz with amplitude 392.9491
# frequency = 5653.7065 Hz with amplitude 362.9667
# frequency = 5654.4169 Hz with amplitude 371.0309
# frequency = 5655.0483 Hz with amplitude 566.5207
# frequency = 5655.1273 Hz with amplitude 441.5773
# frequency = 5655.2851 Hz with amplitude 462.3389
# frequency = 5655.8376 Hz with amplitude 377.368
# frequency = 5657.1005 Hz with amplitude 404.6838
# frequency = 5657.653 Hz with amplitude 544.4094
# frequency = 5657.8109 Hz with amplitude 405.9651
# frequency = 5660.5735 Hz with amplitude 525.7654
# frequency = 5662.7046 Hz with amplitude 525.5109
# frequency = 5662.9414 Hz with amplitude 373.2249
# frequency = 5664.3621 Hz with amplitude 364.1639
# frequency = 5666.6511 Hz with amplitude 421.4351
# frequency = 5671.9394 Hz with amplitude 360.2775
# frequency = 5673.0445 Hz with amplitude 350.8162
# frequency = 5673.518 Hz with amplitude 441.8635
# frequency = 5674.3073 Hz with amplitude 359.7475
# frequency = 5675.7281 Hz with amplitude 406.0141
# frequency = 5682.674 Hz with amplitude 354.4604
# frequency = 5683.1476 Hz with amplitude 428.2327
# frequency = 5683.4633 Hz with amplitude 390.1018
# frequency = 5685.0419 Hz with amplitude 371.622
# frequency = 5686.6994 Hz with amplitude 411.8396
# frequency = 5688.9095 Hz with amplitude 382.528
# frequency = 5692.0667 Hz with amplitude 357.9988
# frequency = 5693.4874 Hz with amplitude 358.0271
# frequency = 5697.6707 Hz with amplitude 358.2935
# frequency = 5719.5345 Hz with amplitude 353.5674
# frequency = 5732.7948 Hz with amplitude 420.3474
# frequency = 5733.4262 Hz with amplitude 372.9591
# frequency = 5733.7419 Hz with amplitude 411.0883
# frequency = 5734.2945 Hz with amplitude 453.854
# frequency = 5735.1627 Hz with amplitude 403.3557
# frequency = 5736.8202 Hz with amplitude 408.4459
# frequency = 5752.2117 Hz with amplitude 381.5019
# frequency = 5752.2906 Hz with amplitude 411.7612
# frequency = 5752.5274 Hz with amplitude 410.9531
# frequency = 5754.8164 Hz with amplitude 355.6775
# frequency = 5755.0532 Hz with amplitude 356.9748
# frequency = 5758.9997 Hz with amplitude 411.6056
# frequency = 5770.8392 Hz with amplitude 353.4598
# frequency = 5770.9182 Hz with amplitude 400.0675
# frequency = 5773.2861 Hz with amplitude 359.4681
# frequency = 5777.864 Hz with amplitude 399.9699
# frequency = 5786.1517 Hz with amplitude 370.3298
# frequency = 5786.4675 Hz with amplitude 357.0048
# frequency = 5789.23 Hz with amplitude 361.5689
# frequency = 5791.2033 Hz with amplitude 360.464
# frequency = 5791.7558 Hz with amplitude 425.5506
# frequency = 5792.4662 Hz with amplitude 452.0012
# frequency = 5794.5184 Hz with amplitude 418.5906
# frequency = 5795.3866 Hz with amplitude 476.6806
# frequency = 5796.1759 Hz with amplitude 382.2167
# frequency = 5798.386 Hz with amplitude 448.1058
# frequency = 5798.7806 Hz with amplitude 396.469
# frequency = 5812.7513 Hz with amplitude 390.303
# frequency = 5814.3299 Hz with amplitude 360.9395
# frequency = 5817.566 Hz with amplitude 381.0143
# frequency = 5822.2229 Hz with amplitude 362.7766
# frequency = 5822.5387 Hz with amplitude 381.5658
# frequency = 5832.0892 Hz with amplitude 442.043
# frequency = 5839.5087 Hz with amplitude 470.7924
# frequency = 5843.2184 Hz with amplitude 459.0763
# frequency = 5850.0854 Hz with amplitude 440.5871
# frequency = 5850.3222 Hz with amplitude 389.3082
# frequency = 5855.1369 Hz with amplitude 363.1253
# frequency = 5860.3463 Hz with amplitude 404.0926
# frequency = 5869.0287 Hz with amplitude 389.8063
# frequency = 5890.0242 Hz with amplitude 356.5457
# frequency = 5890.6556 Hz with amplitude 371.2803
# frequency = 5904.4684 Hz with amplitude 369.779
# frequency = 5908.0992 Hz with amplitude 402.6097
# frequency = 5913.2297 Hz with amplitude 438.0024
# frequency = 5913.4665 Hz with amplitude 397.6005
# frequency = 5916.1501 Hz with amplitude 398.5145
# frequency = 5916.3869 Hz with amplitude 419.124
# frequency = 5916.5448 Hz with amplitude 374.9168
# frequency = 5918.597 Hz with amplitude 459.2328
# frequency = 5923.096 Hz with amplitude 352.3335
# frequency = 5928.1476 Hz with amplitude 356.7599
# frequency = 5930.1208 Hz with amplitude 448.8386
# frequency = 5931.3048 Hz with amplitude 386.0129
# frequency = 5931.3837 Hz with amplitude 367.2088
# frequency = 5932.0941 Hz with amplitude 361.6271
# frequency = 5946.5383 Hz with amplitude 351.9498
# frequency = 5947.2487 Hz with amplitude 385.0794
# frequency = 5950.0113 Hz with amplitude 352.5495
# frequency = 5954.9839 Hz with amplitude 372.5808
# frequency = 5964.2188 Hz with amplitude 353.2378
# frequency = 5967.4549 Hz with amplitude 361.2032
# frequency = 5980.7152 Hz with amplitude 351.8561
# frequency = 5985.1353 Hz with amplitude 373.2008
# frequency = 5987.1875 Hz with amplitude 358.1456
# frequency = 5987.2664 Hz with amplitude 378.0163
# frequency = 5993.0284 Hz with amplitude 419.2517
# frequency = 5994.1334 Hz with amplitude 397.7348
# frequency = 5994.2123 Hz with amplitude 445.7465
# frequency = 5994.2912 Hz with amplitude 396.7139
# frequency = 5995.7909 Hz with amplitude 354.3669
# frequency = 5997.0538 Hz with amplitude 401.6205
# frequency = 5998.3167 Hz with amplitude 356.2275
# frequency = 6001.6318 Hz with amplitude 373.3523
# frequency = 6006.7622 Hz with amplitude 411.6034
# frequency = 6008.9723 Hz with amplitude 422.3042
# frequency = 6009.4459 Hz with amplitude 370.4852
# frequency = 6010.7088 Hz with amplitude 363.864
# frequency = 6019.3911 Hz with amplitude 393.4374
# frequency = 6022.3905 Hz with amplitude 398.4694
# frequency = 6022.4694 Hz with amplitude 357.687
# frequency = 6024.7584 Hz with amplitude 393.918
# frequency = 6025.3898 Hz with amplitude 364.7283
# frequency = 6028.9417 Hz with amplitude 384.2841
# frequency = 6029.4153 Hz with amplitude 356.1515
# frequency = 6030.6782 Hz with amplitude 371.991
# frequency = 6032.2568 Hz with amplitude 356.9206
# frequency = 6032.8093 Hz with amplitude 428.7464
# frequency = 6035.0193 Hz with amplitude 360.4744
# frequency = 6042.4388 Hz with amplitude 427.5046
# frequency = 6043.2281 Hz with amplitude 385.5219
# frequency = 6043.307 Hz with amplitude 377.9092
# frequency = 6044.8067 Hz with amplitude 362.8926
# frequency = 6045.1224 Hz with amplitude 432.8366
# frequency = 6048.1218 Hz with amplitude 354.3586
# frequency = 6048.2007 Hz with amplitude 360.541
# frequency = 6053.1733 Hz with amplitude 352.0988
# frequency = 6055.9359 Hz with amplitude 370.3986
# frequency = 6056.0938 Hz with amplitude 355.848
# frequency = 6056.8041 Hz with amplitude 352.0197
# frequency = 6059.8035 Hz with amplitude 452.3576
# frequency = 6062.7239 Hz with amplitude 375.7284
# frequency = 6064.5393 Hz with amplitude 358.2099
# frequency = 6065.6443 Hz with amplitude 435.3675
# frequency = 6065.9601 Hz with amplitude 371.0543
# frequency = 6067.4597 Hz with amplitude 483.3931
# frequency = 6068.249 Hz with amplitude 396.8596
# frequency = 6069.6698 Hz with amplitude 375.4086
# frequency = 6069.8276 Hz with amplitude 485.8647
# frequency = 6069.9066 Hz with amplitude 355.5672
# frequency = 6070.3802 Hz with amplitude 540.1574
# frequency = 6070.4591 Hz with amplitude 364.3699
# frequency = 6070.538 Hz with amplitude 522.7388
# frequency = 6070.6169 Hz with amplitude 407.5207
# frequency = 6070.7748 Hz with amplitude 372.1214
# frequency = 6071.1695 Hz with amplitude 393.9128
# frequency = 6072.3534 Hz with amplitude 391.8288
# frequency = 6073.3006 Hz with amplitude 350.983
# frequency = 6074.0899 Hz with amplitude 463.1196
# frequency = 6079.2993 Hz with amplitude 374.8106
# frequency = 6085.6137 Hz with amplitude 364.9491
# frequency = 6095.2432 Hz with amplitude 420.0237
# frequency = 6097.1376 Hz with amplitude 394.8808
# frequency = 6097.9269 Hz with amplitude 401.5774
# frequency = 6098.2426 Hz with amplitude 392.7013
# frequency = 6103.7677 Hz with amplitude 372.9997
# frequency = 6105.662 Hz with amplitude 357.3432
# frequency = 6106.2935 Hz with amplitude 435.3858
# frequency = 6107.3985 Hz with amplitude 351.6431
# frequency = 6107.7932 Hz with amplitude 388.45
# frequency = 6110.9504 Hz with amplitude 395.2534
# frequency = 6113.3183 Hz with amplitude 350.5388
# frequency = 6113.5551 Hz with amplitude 352.3808
# frequency = 6114.4233 Hz with amplitude 436.9554
# frequency = 6123.9739 Hz with amplitude 352.1305
# frequency = 6124.2896 Hz with amplitude 391.648
# frequency = 6128.6308 Hz with amplitude 413.2382
# frequency = 6132.3405 Hz with amplitude 375.5264
# frequency = 6134.9452 Hz with amplitude 438.9801
# frequency = 6140.2336 Hz with amplitude 382.3521
# frequency = 6140.7072 Hz with amplitude 355.5074
# frequency = 6142.8383 Hz with amplitude 351.7063
# frequency = 6152.5467 Hz with amplitude 357.9846
# frequency = 6176.8573 Hz with amplitude 431.7544
# frequency = 6181.2774 Hz with amplitude 358.8247
# frequency = 6190.9069 Hz with amplitude 370.8524
# frequency = 6193.1959 Hz with amplitude 358.9258
# frequency = 6194.9323 Hz with amplitude 446.3096
# frequency = 6199.5103 Hz with amplitude 366.7963
# frequency = 6200.2996 Hz with amplitude 373.6474
# frequency = 6203.22 Hz with amplitude 367.2322
# frequency = 6203.7726 Hz with amplitude 350.6239
# frequency = 6205.8247 Hz with amplitude 435.1089
# frequency = 6206.9298 Hz with amplitude 357.8431
# frequency = 6207.4823 Hz with amplitude 361.2692
# frequency = 6207.5612 Hz with amplitude 406.8273
# frequency = 6209.5345 Hz with amplitude 360.7898
# frequency = 6209.8502 Hz with amplitude 480.8922
# frequency = 6220.1901 Hz with amplitude 433.4175
# frequency = 6229.5039 Hz with amplitude 368.7752
# frequency = 6231.635 Hz with amplitude 359.9235
# frequency = 6239.1334 Hz with amplitude 422.2725
# frequency = 6239.2123 Hz with amplitude 365.0591
# frequency = 6249.3154 Hz with amplitude 365.6642
# frequency = 6250.9729 Hz with amplitude 420.2731
# frequency = 6253.183 Hz with amplitude 458.5792
# frequency = 6267.1537 Hz with amplitude 353.9868
# frequency = 6273.3102 Hz with amplitude 375.4466
# frequency = 6276.0728 Hz with amplitude 393.9045
# frequency = 6285.1498 Hz with amplitude 350.4988
# frequency = 6288.0702 Hz with amplitude 477.6177
# frequency = 6295.095 Hz with amplitude 447.8508
# frequency = 6298.8048 Hz with amplitude 361.1068
# frequency = 6304.5667 Hz with amplitude 389.667
# frequency = 6315.6959 Hz with amplitude 369.7163
# frequency = 6317.7481 Hz with amplitude 359.366
# frequency = 6318.6952 Hz with amplitude 363.0171
# frequency = 6320.2738 Hz with amplitude 446.8309
# frequency = 6322.405 Hz with amplitude 420.2828
# frequency = 6322.4839 Hz with amplitude 361.7957
# frequency = 6323.6678 Hz with amplitude 383.1485
# frequency = 6325.0097 Hz with amplitude 439.5745
# frequency = 6325.0886 Hz with amplitude 357.5084
# frequency = 6325.2465 Hz with amplitude 375.7606
# frequency = 6325.4043 Hz with amplitude 370.06
# frequency = 6327.2197 Hz with amplitude 350.7399
# frequency = 6328.009 Hz with amplitude 362.6289
# frequency = 6328.1669 Hz with amplitude 538.8063
# frequency = 6335.981 Hz with amplitude 409.0605
# frequency = 6343.1637 Hz with amplitude 409.4052
# frequency = 6345.7684 Hz with amplitude 382.6763
# frequency = 6360.2126 Hz with amplitude 414.305
# frequency = 6362.4227 Hz with amplitude 350.8176
# frequency = 6362.9752 Hz with amplitude 422.9346
# frequency = 6363.7645 Hz with amplitude 393.1808
# frequency = 6363.9224 Hz with amplitude 433.6684
# frequency = 6364.7906 Hz with amplitude 375.4535
# frequency = 6365.7378 Hz with amplitude 404.2146
# frequency = 6366.0535 Hz with amplitude 418.0613
# frequency = 6366.1324 Hz with amplitude 443.9154
# frequency = 6368.5793 Hz with amplitude 379.014
# frequency = 6368.6582 Hz with amplitude 384.6182
# frequency = 6369.4475 Hz with amplitude 389.7684
# frequency = 6373.5519 Hz with amplitude 414.9409
# frequency = 6375.2883 Hz with amplitude 404.9466
# frequency = 6379.3927 Hz with amplitude 367.4733
# frequency = 6384.3653 Hz with amplitude 362.6605
# frequency = 6388.7854 Hz with amplitude 388.087
# frequency = 6392.8898 Hz with amplitude 394.9629
# frequency = 6396.9942 Hz with amplitude 386.6257
# frequency = 6398.9675 Hz with amplitude 426.1923
# frequency = 6399.5989 Hz with amplitude 377.8196
# frequency = 6400.2303 Hz with amplitude 365.0619
# frequency = 6403.3876 Hz with amplitude 359.0512
# frequency = 6409.3073 Hz with amplitude 354.6028
# frequency = 6431.0132 Hz with amplitude 364.1025
# frequency = 6440.8006 Hz with amplitude 357.1047
# frequency = 6444.0367 Hz with amplitude 379.782
# frequency = 6476.7139 Hz with amplitude 381.1648
# frequency = 6497.078 Hz with amplitude 351.1122
# frequency = 6534.9646 Hz with amplitude 355.3087
# frequency = 6538.5954 Hz with amplitude 423.3124
# frequency = 6544.4362 Hz with amplitude 372.0644
# frequency = 6544.9887 Hz with amplitude 354.2432
# frequency = 6545.1466 Hz with amplitude 366.2364
# frequency = 6553.3553 Hz with amplitude 376.4984
# frequency = 6557.4597 Hz with amplitude 436.0271
# frequency = 6560.0644 Hz with amplitude 356.3034
# frequency = 6561.8798 Hz with amplitude 384.1213
# frequency = 6564.2477 Hz with amplitude 449.3506
# frequency = 6564.8003 Hz with amplitude 386.657
# frequency = 6566.3789 Hz with amplitude 356.981
# frequency = 6568.51 Hz with amplitude 421.2579
# frequency = 6570.5622 Hz with amplitude 364.6356
# frequency = 6596.7671 Hz with amplitude 354.7996
# frequency = 6629.2075 Hz with amplitude 356.8326
# frequency = 6629.76 Hz with amplitude 415.2818
# frequency = 6633.6276 Hz with amplitude 362.6563
# frequency = 6641.2838 Hz with amplitude 357.8556
# frequency = 6659.1221 Hz with amplitude 409.5635
# frequency = 6664.884 Hz with amplitude 351.1363
# frequency = 6665.0419 Hz with amplitude 351.7609
# frequency = 6669.1463 Hz with amplitude 391.9712
# frequency = 6675.9343 Hz with amplitude 377.3835
# frequency = 6698.903 Hz with amplitude 354.0048
# frequency = 6703.6389 Hz with amplitude 359.2124
# frequency = 6704.4282 Hz with amplitude 418.5727
# frequency = 6709.2429 Hz with amplitude 361.4396
# frequency = 6719.346 Hz with amplitude 378.802
# frequency = 6739.1575 Hz with amplitude 350.7661
# frequency = 6746.7349 Hz with amplitude 390.9915
# frequency = 6747.3663 Hz with amplitude 407.9085
# frequency = 6755.8908 Hz with amplitude 376.9184
# frequency = 6758.4955 Hz with amplitude 394.3732
# frequency = 6769.5457 Hz with amplitude 367.9345
# frequency = 6874.2864 Hz with amplitude 350.3825
# frequency = 6999.1543 Hz with amplitude 351.1442
# frequency = 6999.3122 Hz with amplitude 381.2971
# frequency = 6999.7858 Hz with amplitude 367.9482
# frequency = 7193.9546 Hz with amplitude 370.0787
# frequency = 7294.5119 Hz with amplitude 365.3847
