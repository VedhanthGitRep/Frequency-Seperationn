# %%
pip install wavfile
# Out:
# Collecting wavfile
#   Downloading wavfile-0.4.0-py3-none-any.whl (11 kB)
# Installing collected packages: wavfile
# Successfully installed wavfile-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install noisereduce
# Out:
# Collecting noisereduce
#   Downloading noisereduce-2.0.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in c:\users\vedhanth\anaconda3\lib\site-packages (from noisereduce) (1.19.5)
# Requirement already satisfied: scipy in c:\users\vedhanth\anaconda3\lib\site-packages (from noisereduce) (1.6.2)
# Requirement already satisfied: matplotlib in c:\users\vedhanth\anaconda3\lib\site-packages (from noisereduce) (3.3.4)
# Requirement already satisfied: joblib in c:\users\vedhanth\anaconda3\lib\site-packages (from noisereduce) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\vedhanth\anaconda3\lib\site-packages (from noisereduce) (4.59.0)
# Requirement already satisfied: librosa in c:\users\vedhanth\anaconda3\lib\site-packages (from noisereduce) (0.8.1)
# Requirement already satisfied: numba>=0.43.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (0.53.1)
# Requirement already satisfied: decorator>=3.0.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (5.0.6)
# Requirement already satisfied: audioread>=2.0.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (0.2.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (0.24.1)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (20.9)
# Requirement already satisfied: pooch>=1.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from librosa->noisereduce) (1.4.0)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\vedhanth\anaconda3\lib\site-packages (from numba>=0.43.0->librosa->noisereduce) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\vedhanth\anaconda3\lib\site-packages (from numba>=0.43.0->librosa->noisereduce) (52.0.0.post20210125)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vedhanth\anaconda3\lib\site-packages (from packaging>=20.0->librosa->noisereduce) (2.4.7)
# Requirement already satisfied: appdirs in c:\users\vedhanth\anaconda3\lib\site-packages (from pooch>=1.0->librosa->noisereduce) (1.4.4)
# Requirement already satisfied: requests in c:\users\vedhanth\anaconda3\lib\site-packages (from pooch>=1.0->librosa->noisereduce) (2.25.1)
# Requirement already satisfied: six>=1.3 in c:\users\vedhanth\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa->noisereduce) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa->noisereduce) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa->noisereduce) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\vedhanth\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->noisereduce) (2.20)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vedhanth\anaconda3\lib\site-packages (from matplotlib->noisereduce) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\vedhanth\anaconda3\lib\site-packages (from matplotlib->noisereduce) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from matplotlib->noisereduce) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\vedhanth\anaconda3\lib\site-packages (from matplotlib->noisereduce) (0.10.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vedhanth\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vedhanth\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vedhanth\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vedhanth\anaconda3\lib\site-packages (from requests->pooch>=1.0->librosa->noisereduce) (2020.12.5)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install soundfile
# Out:
# Requirement already satisfied: soundfile in c:\users\vedhanth\anaconda3\lib\site-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from soundfile) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\vedhanth\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\vedhanth\anaconda3\lib\site-packages (7.22.0)
# Requirement already satisfied: backcall in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (52.0.0.post20210125)
# Requirement already satisfied: pickleshare in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (0.7.5)
# Requirement already satisfied: pygments in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (2.8.1)
# Requirement already satisfied: colorama in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (3.0.17)
# Requirement already satisfied: traitlets>=4.2 in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (0.17.2)
# Requirement already satisfied: decorator in c:\users\vedhanth\anaconda3\lib\site-packages (from IPython) (5.0.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\vedhanth\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\vedhanth\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\vedhanth\anaconda3\lib\site-packages (from traitlets>=4.2->IPython) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import IPython
from scipy.io import wavfile
import noisereduce as nr
import soundfile as sf
from noisereduce.generate_noise import band_limited_noise
import matplotlib.pyplot as plt
import urllib.request
import numpy as np
import io
# %matplotlib inline

# %%
url = "https://raw.githubusercontent.com/timsainb/noisereduce/master/assets/fish.wav"
response = urllib.request.urlopen(url)
data, rate = sf.read(io.BytesIO(response.read()))
data = data

# %%
IPython.display.Audio(data=data, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(data)

# %%
noise_len = 2 # seconds
noise = band_limited_noise(min_freq=2000, max_freq = 12000, samples=len(data), samplerate=rate)*10
noise_clip = noise[:rate*noise_len]
audio_clip_band_limited = data+noise

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(audio_clip_band_limited)

# %%
IPython.display.Audio(data=audio_clip_band_limited, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
reduced_noise = nr.reduce_noise(y = audio_clip_band_limited, sr=rate, n_std_thresh_stationary=1.5, stationary=True)

# %%
fig, ax = plt.subplots(fdigsize=(20,3))
ax.plot(reduced_noise)

# %%
IPython.display.Audio(data=reduced_noise, rate=rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
reduced_noise = nr.reduce_noise(y = audio_clip_band_limited, sr=rate, thresh_n_mult_nonstationary=2,stationary=False)

# %%
fig, ax = plt.subplots(figsize=(20,3))
ax.plot(reduced_noise)

# %% [markdown]
# ADD NOISE TO THE DATA

# %% [markdown]
# fig, ax = plt.subplots(figsize=(20,4))
# ax.plot(audio_clip_cafe)
# IPython.display.Audio(data=audio_clip_cafe, rate=noise_rate)

# %%
noisereduce --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2ba7007940ae> in <module>
# ----> 1 noisereduce --version
#
# NameError: name 'noisereduce' is not defined
